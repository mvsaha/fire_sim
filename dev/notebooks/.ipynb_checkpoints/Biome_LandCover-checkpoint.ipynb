# %%
import sys
sys.path.append('../')
sys.dont_write_bytecode = True
import os
import numpy as np
import scipy
import scipy.ndimage
from matplotlib.pyplot import *
# %matplotlib inline
import numba
sys.path.append('/Users/Michael_Saha/Repositories/')
sys.path.append('./../../../')
from fire_sim import *
# Out:
# Vendor:  Continuum Analytics, Inc.
# Package: mkl
# Message: trial mode expires in 21 days

# %%
import gdal
#c = '/Users/Michael_Saha/DATA/FotF/classed1/classed1.tif'
c = 'E:/DATA/FotF/classed/classed1.tif'
C = gdal.Open(c).ReadAsArray()

# %%
C.shape
# Out:
# (10596, 12231)

# %%
(np.array(C.shape)/10).astype(int)
# Out:
# array([1059, 1223])

# %%
c = scipy.misc.imresize(C, (np.array(C.shape)/10).astype(int) )

# %%
c.shape

# Each fire is a list of pixels
# Out:
# (1059, 1223)

# %%
figure(figsize=(15,15))
imshow(c)
clim(0,8)
colorbar()

# %%
from osgeo import ogr
perims_file = '/Volumes/SAHA/DATA/FotF/perims_SANDAG/fire_burn_history_proj.shp'

# %%
shp_driver = ogr.GetDriverByName('ESRI Shapefile')
x = shp_driver.Open(perims_file)
print(x[0])
s = x[0]
s.GetExtent()
f = s.GetNextFeature()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-54c8a0eb4eee> in <module>()
#       1 shp_driver = ogr.GetDriverByName('ESRI Shapefile')
#       2 x = shp_driver.Open(perims_file)
# ----> 3 print(x[0])
#       4 s = x[0]
#       5 s.GetExtent()
#
# TypeError: 'NoneType' object is not subscriptable

# %%
g = f.geometry()
list(g)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-03609fcb203e> in <module>()
# ----> 1 g = f.geometry()
#       2 list(g)
#
# NameError: name 'f' is not defined

# %%
c = g.Centroid()
# Out:
# (0.0, 0.0, 0.0)

# %%
c = g.GetCurveGeometry()
c.GetPoint()
# Out:
# (6.95321986655713e-310, 2.1221942334e-314, 2.240834693e-314)

# %%
[i for i in g.]
# Out:
# [<osgeo.ogr.Geometry; proxy of <Swig Object of type 'OGRGeometryShadow *' at 0x120bcd5a0> >]

# %%
f.GetField(6)
# Out:
#   File "<ipython-input-110-62f926234309>", line 2
#     7)
#     ^
# SyntaxError: invalid syntax

# %%
f = s.GetFeature(5)
f.items()
# Out:
# {'ACRES_CALC': 1.98708181,
#  'AGENCY_MAT': 'CDF',
#  'ALARM_DATE': 20120813,
#  'CAUSE': 'Lightning',
#  'CAUSECODE': 1.0,
#  'COMMENTS': 'VALLECITO LIGHTNING COMPLEX',
#  'CONT_DATE': 20120820,
#  'COST': 0,
#  'C_METHOD': 8,
#  'DAY_': 13.0,
#  'FIRE_NAME': 'SHOOTS',
#  'FIRE_NUM': '008747',
#  'GIS_ACRES': 1.98725915,
#  'INC_NUM': '008747',
#  'MONTH_': 8.0,
#  'OBJECTIVE': 1,
#  'PERIMETER': 1179.23509966,
#  'REPORT_AC': 22829.0,
#  'SHAPE_AREA': 86556.9376053,
#  'SHAPE_LEN': 1179.23509968,
#  'SHAPE_LENG': 0.0,
#  'UNIQUE_ID': '2012CAMVU008747',
#  'UNIT_ID': 'MVU',
#  'YEAR_': '2012'}

# %%
l = x.GetLayer()
l.GetNextFeature()
